// %% [markdown]
// ## Google Colab Rust Setup
//
// The following cell is used to set up a Rust environment on Colab. Don't execute it locally!
//
// Many thanks to [`mateusvmv`](https://github.com/mateusvmv) for this hack in [`gist.github.com/korakot/ae95315ea6a3a3b33ee26203998a59a3`](https://gist.github.com/korakot/ae95315ea6a3a3b33ee26203998a59a3?permalink_comment_id=4715636#gistcomment-4715636).

// %%
# This script sets up and spins up a Jupyter Notebook environment with a Rust kernel using Nix and IPC Proxy. 
!wget -qO- https://gist.github.com/wiseaidev/2af6bef753d48565d11bcd478728c979/archive/3f6df40db09f3517ade41997b541b81f0976c12e.tar.gz | tar xvz --strip-components=1
!bash setup_evcxr_kernel.sh

// %% [markdown]
// ## Install Dependencies

// %%
:dep chrono = { version = "=0.4.41" } // pin because of polars V0.53.0 depends on it.
// or
// :dep chrono = { git = "https://github.com/chronotope/chrono" }

// %%
:dep polars = { version = "0.53.0", features = ["describe", "lazy", "ndarray", "object", "dtype-struct", "concat_str", "mode"] }
// or
// :dep blas-src = { git = "https://github.com/pola-rs/polars", features = ["describe", "lazy", "ndarray", "object", "dtype-struct", "concat_str", "mode"]}

// %% [markdown]
// <hr />

// %% [markdown]
// ## Import Libraries

// %%
use polars::datatypes::DataType;
use polars::prelude::*;
use chrono::{DateTime, NaiveDateTime, TimeZone, Utc};
use std::sync::Arc;

// %% [markdown]
// <hr />

// %% [markdown]
// ## Series Object

// %%
let series1: Series = [1, 2, 3].iter().collect();
// or
// let series1: Series = Series::new("", &[1, 2, 3]);
series1
// Out:
// shape: (3,)
// Series: '' [i32]
// [
// 	1
// 	2
// 	3
// ]

// %%
let seasons_ser: Series = Series::new("seasons".into(), &["Winter", "Spring", "Summer", "Fall"]);
seasons_ser
// Out:
// shape: (4,)
// Series: 'seasons' [str]
// [
// 	"Winter"
// 	"Spring"
// 	"Summer"
// 	"Fall"
// ]

// %%
let s: Series = Series::new("seasons".into(), &[None, Some(1), Some(2)]);
s
// Out:
// shape: (3,)
// Series: 'seasons' [i32]
// [
// 	null
// 	1
// 	2
// ]

// %%
Some(f64::NAN)==None
// Out:
// false

// %%
f64::NAN==f64::NAN
// Out:
// false

// %%
let s: Series = Series::new("seasons".into(), &[None, Some(1), Some(2)]);
s.null_count()
// Out:
// 1

// %%
s.drop_nulls()
// Out:
// shape: (2,)
// Series: 'seasons' [i32]
// [
// 	1
// 	2
// ]

// %%
let s: Series = Series::new("numbers".into(), &[Some(f64::NAN), Some(1.), Some(2.)]);
s.cast(&DataType::Int64).unwrap()
// Out:
// shape: (3,)
// Series: 'numbers' [i64]
// [
// 	null
// 	1
// 	2
// ]

// %% [markdown]
// ## Series Creation

// %%
let s = Series::new_empty("Height".into(), &DataType::Float32);
s
// Out:
// Couldn't automatically determine type of variable `s`.
// Please give it an explicit type.

// %%
let s: Series = Series::new("employees".into(), &["Mahmoud", "Ferris"]);
s
// Out:
// shape: (2,)
// Series: 'employees' [str]
// [
// 	"Mahmoud"
// 	"Ferris"
// ]

// %%
let s: Series = Series::new("employees".into(), &["Mahmoud", "Ferris"]);
s.name()
// Out:
// "employees"

// %%
let s: Series = Series::new("employees".into(), &vec!["Mahmoud", "Ferris"]);
s
// Out:
// shape: (2,)
// Series: 'employees' [str]
// [
// 	"Mahmoud"
// 	"Ferris"
// ]

// %%
let s: Series = Float64Chunked::new("b".into(), &[1., 2., 3.]).into_series();
s
// Out:
// shape: (3,)
// Series: 'b' [f64]
// [
// 	1.0
// 	2.0
// 	3.0
// ]

// %% [markdown]
// ## Datetime Type

// %%
let date: DateTime<Utc> = Utc.with_ymd_and_hms(2020, 1, 1, 0, 0, 0).unwrap();
let s: Series = Series::new("b".into(), &[date.date_naive()]);
s
// Out:
// shape: (1,)
// Series: 'b' [date]
// [
// 	2020-01-01
// ]

// %% [markdown]
// ## Indexing & Slicing

// %%
let s: Series = Series::new("employees".into(), &vec!["Ferris", "Mahmoud"]);
s
// Out:
// shape: (2,)
// Series: 'employees' [str]
// [
// 	"Ferris"
// 	"Mahmoud"
// ]

// %%
let s: Series = Series::new("employees".into(), &vec!["Mahmoud", "Ferris"]);
s.slice(0, 1)
// Out:
// shape: (1,)
// Series: 'employees' [str]
// [
// 	"Mahmoud"
// ]

// %% [markdown]
// ## Length

// %%
let s: Series = Series::new("employees".into(), &vec!["Mahmoud", "Ferris"]);
s.len()
// Out:
// 2

// %% [markdown]
// ## Reverse

// %%
let s: Series = Series::new("employees".into(), &vec!["Mahmoud", "Ferris"]);
s.reverse()
// Out:
// shape: (2,)
// Series: 'employees' [str]
// [
// 	"Ferris"
// 	"Mahmoud"
// ]

// %% [markdown]
// ## Empty

// %%
let s: Series = Series::new("employees".into(), &vec!["Mahmoud", "Ferris"]);
s.is_empty()
// Out:
// false

// %% [markdown]
// ## Drop nulls

// %%
let s: Series = Series::new("employees".into(), &vec![Some("Ferris"), None]);
s.drop_nulls()
// Out:
// shape: (1,)
// Series: 'employees' [str]
// [
// 	"Ferris"
// ]

// %% [markdown]
// ## Summarizing Series

// %%
let s: Series = Series::new("Measurements".into(), &[-1.01,  0.86, -4.60, 3.98,  0.53, -7.04, 3.98,  0.53, -7.04, 0.86, 0.16, 0.26, 0.81]);

// First 10 rows
s.head(None)
// Out:
// shape: (10,)
// Series: 'Measurements' [f64]
// [
// 	-1.01
// 	0.86
// 	-4.6
// 	3.98
// 	0.53
// 	-7.04
// 	3.98
// 	0.53
// 	-7.04
// 	0.86
// ]

// %%
let s: Series = Series::new("Measurements".into(), &[-1.01,  0.86, -4.60, 3.98,  0.53, -7.04, 3.98,  0.53, -7.04, 0.86, 0.16, 0.26, 0.81]);

// First 5 rows
s.head(Some(5))
// Out:
// shape: (5,)
// Series: 'Measurements' [f64]
// [
// 	-1.01
// 	0.86
// 	-4.6
// 	3.98
// 	0.53
// ]

// %%
let s: Series = Series::new("Measurements".into(), &[-1.01,  0.86, -4.60, 3.98,  0.53, -7.04, 3.98,  0.53, -7.04, 0.86, 0.16, 0.26, 0.81]);

// Last 10 rows
s.tail(None)
// Out:
// shape: (10,)
// Series: 'Measurements' [f64]
// [
// 	3.98
// 	0.53
// 	-7.04
// 	3.98
// 	0.53
// 	-7.04
// 	0.86
// 	0.16
// 	0.26
// 	0.81
// ]

// %% [markdown]
// ## Append

// %%
let mut s1: Series = Series::new("Age".into(), &[23., 27.]);
let s2: Series = Series::new("Height".into(), &[1.84, 1.78]);
s1.append(&s2)
// Out:
// Ok(shape: (4,)
// Series: 'Age' [f64]
// [
// 	23.0
// 	27.0
// 	1.84
// 	1.78
// ])

// %% [markdown]
// ## Cast

// %%
let mut s: Series = Series::new("Measurements".into(), &[-1.01,  0.86, -4.60, 3.98,  0.53, -7.04, 3.98,  0.53, -7.04]);
s.cast(&DataType::Int32).unwrap()
// Out:
// shape: (9,)
// Series: 'Measurements' [i32]
// [
// 	-1
// 	0
// 	-4
// 	3
// 	0
// 	-7
// 	3
// 	0
// 	-7
// ]

// %% [markdown]
// ## Fill Nulls

// %% [markdown]
// ### 1. Forward fill

// %%
let s: Series = Series::new("some_missing".into(), &[Some(1), None, Some(3), Some(4), None, Some(6)]);
let filled: Series = s.fill_null(FillNullStrategy::Forward(None))?;
filled
// Out:
// shape: (6,)
// Series: 'some_missing' [i32]
// [
// 	1
// 	1
// 	3
// 	4
// 	4
// 	6
// ]

// %% [markdown]
// ### 2. Backward fill

// %%
let s: Series = Series::new("some_missing".into(), &[Some(1), None, Some(3), Some(4), None, Some(6)]);
let filled: Series = s.fill_null(FillNullStrategy::Backward(None))?;
filled
// Out:
// shape: (6,)
// Series: 'some_missing' [i32]
// [
// 	1
// 	3
// 	3
// 	4
// 	6
// 	6
// ]

// %% [markdown]
// ### 3. Mean fill

// %%
let s: Series = Series::new("some_missing".into(), &[Some(1), None, Some(3), Some(4), None, Some(6)]);
let filled: Series = s.fill_null(FillNullStrategy::Mean)?;
filled
// Out:
// shape: (6,)
// Series: 'some_missing' [i32]
// [
// 	1
// 	3
// 	3
// 	4
// 	3
// 	6
// ]

// %% [markdown]
// ### 4. Min fill

// %%
let s: Series = Series::new("some_missing".into(), &[Some(1), None, Some(3), Some(4), None, Some(6)]);
let filled: Series = s.fill_null(FillNullStrategy::Min)?;
filled
// Out:
// shape: (6,)
// Series: 'some_missing' [i32]
// [
// 	1
// 	1
// 	3
// 	4
// 	1
// 	6
// ]

// %% [markdown]
// ### 5. Max fill

// %%
let s: Series = Series::new("some_missing".into(), &[Some(1), None, Some(3), Some(4), None, Some(6)]);
let filled: Series = s.fill_null(FillNullStrategy::Max)?;
filled
// Out:
// shape: (6,)
// Series: 'some_missing' [i32]
// [
// 	1
// 	6
// 	3
// 	4
// 	6
// 	6
// ]

// %% [markdown]
// ## Sampling

// %%
let s: Series = Series::new("Measurements".into(), &[-1.01,  0.86, -4.60, 3.98,  0.53, -7.04, 3.98,  0.53, -7.04]);
// Take 4 samples with replacement and with shuffle (we are talkin' probability here).
s.sample_n(4, true, true, Some(9999))
// Out:
// Ok(shape: (4,)
// Series: 'Measurements' [f64]
// [
// 	0.86
// 	-7.04
// 	-1.01
// 	-7.04
// ])

// %% [markdown]
// ## Descriptive statistics

// %% [markdown]
// ### Measures of central tendency

// %% [markdown]
// ### 1. Mean

// %%
let s: Series = Series::new("Measurements".into(), &[-1.01,  0.86, -4.60, 3.98,  0.53, -7.04, 3.98,  0.53, -7.04]);
s.mean()
// Out:
// Some(-1.09)

// %% [markdown]
// ### 2. Median

// %%
let s: Series = Series::new("Measurements".into(), &[-1.01,  0.86, -4.60, 3.98,  0.53, -7.04, 3.98,  0.53, -7.04]);
s.median()
// Out:
// Some(0.53)

// %% [markdown]
// ### 3. Mode

// %%
let s: Series = Series::new("Measurements".into(), &[-1.01,  0.86, -4.60, 3.98,  0.53, -7.04, 3.98,  0.53, -7.04]);
mode::mode(&s, false)?
// Out:
// shape: (3,)
// Series: 'Measurements' [f64]
// [
// 	3.98
// 	-7.04
// 	0.53
// ]

// %% [markdown]
// ### Measures of spread

// %% [markdown]
// ### 1. Interquartile range

// %%
let s: Series = Series::new("Measurements".into(), &[-1.01,  0.86, -4.60, 3.98,  0.53, -7.04, 3.98,  0.53, -7.04]);
s.quantiles_reduce(&[0.75], QuantileMethod::Nearest)?
// Out:
// Scalar { dtype: List(Float64), value: List(shape: (1,)
// Series: 'quantiles' [f64]
// [
// 	0.86
// ]) }

// %% [markdown]
// ---
// ---
