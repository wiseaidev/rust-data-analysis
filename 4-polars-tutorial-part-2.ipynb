// %% [markdown]
// ## Google Colab Rust Setup
//
// The following cell is used to set up a Rust environment on Colab. Don't execute it locally!
//
// Many thanks to [`mateusvmv`](https://github.com/mateusvmv) for this hack in [`gist.github.com/korakot/ae95315ea6a3a3b33ee26203998a59a3`](https://gist.github.com/korakot/ae95315ea6a3a3b33ee26203998a59a3?permalink_comment_id=4715636#gistcomment-4715636).

// %%
# This script sets up and spins up a Jupyter Notebook environment with a Rust kernel using Nix and IPC Proxy. 
!wget -qO- https://gist.github.com/wiseaidev/2af6bef753d48565d11bcd478728c979/archive/3f6df40db09f3517ade41997b541b81f0976c12e.tar.gz | tar xvz --strip-components=1
!bash setup_evcxr_kernel.sh

// %% [markdown]
// ## Install Dependencies

// %%
:dep polars = { version = "0.53.0", features = ["describe", "lazy", "ndarray", "object", "dtype-struct", "concat_str", "mode"] }
// or
// :dep polars = { git = "https://github.com/pola-rs/polars", features = ["describe", "lazy", "ndarray", "object", "dtype-struct", "concat_str", "mode"]}

// %%
:dep either = { version = "1.15.0" }
// or
// :dep either = { git = "https://github.com/bluss/either" }

// %% [markdown]
// ---

// %% [markdown]
// ## Import Libraries

// %%
use std::path::Path;
use polars::prelude::*;
use either::Either;

// %% [markdown]
// ---

// %% [markdown]
// ## DataFrame Object

// %% [markdown]
// ### DataFrame Initialization

// %%
let df = DataFrame::default();
df
// Out:
// Couldn't automatically determine type of variable `df`.
// Please give it an explicit type.

// %%
let s1: Column = Column::new("Name".into(), &["Mahmoud", "Ali"]);
let s2: Column = Column::new("Age".into(), &[23, 27]);
let s3: Column = Column::new("Height".into(), &[1.84, 1.78]);

let df: DataFrame = DataFrame::new(2, vec![s1, s2, s3])?;
// or let df: DataFrame = DataFrame::new_infer_height(vec![s1, s2, s3])?;
df
// Out:
// shape: (2, 3)
// ┌─────────┬─────┬────────┐
// │ Name    ┆ Age ┆ Height │
// │ ---     ┆ --- ┆ ---    │
// │ str     ┆ i32 ┆ f64    │
// ╞═════════╪═════╪════════╡
// │ Mahmoud ┆ 23  ┆ 1.84   │
// │ Ali     ┆ 27  ┆ 1.78   │
// └─────────┴─────┴────────┘

// %% [markdown]
// ### Describe

// %%
let df1: DataFrame = df!("categorical" => &["d","e","f"],
                         "numeric" => &[1, 2, 3],
                         "object" => &["a", "b", "c"])?;
df1
// Out:
// shape: (3, 3)
// ┌─────────────┬─────────┬────────┐
// │ categorical ┆ numeric ┆ object │
// │ ---         ┆ ---     ┆ ---    │
// │ str         ┆ i32     ┆ str    │
// ╞═════════════╪═════════╪════════╡
// │ d           ┆ 1       ┆ a      │
// │ e           ┆ 2       ┆ b      │
// │ f           ┆ 3       ┆ c      │
// └─────────────┴─────────┴────────┘

// %% [markdown]
// What happened to the `describe` function, ma G?

// %%
// let df2: DataFrame = df1.describe(None)?;
// df2

println!("{}", df1.lazy().logical_plan.describe()?)
// Out:
// DF ["categorical", "numeric", "object"]; PROJECT */3 COLUMNS
// ()

// %% [markdown]
// ### Head

// %%
let df: DataFrame = df!("Name" => &["Mahmoud", "Bob"],
                                      "Age" => &[23, 27],
                                      "Height" => &[1.84, 1.78])?;
// First 10 rows
df.head(None)
// Out:
// shape: (2, 3)
// ┌─────────┬─────┬────────┐
// │ Name    ┆ Age ┆ Height │
// │ ---     ┆ --- ┆ ---    │
// │ str     ┆ i32 ┆ f64    │
// ╞═════════╪═════╪════════╡
// │ Mahmoud ┆ 23  ┆ 1.84   │
// │ Bob     ┆ 27  ┆ 1.78   │
// └─────────┴─────┴────────┘

// %%
let df: DataFrame = df!("Name" => &["Mahmoud", "Bob"],
                                      "Age" => &[23, 27],
                                      "Height" => &[1.84, 1.78])?;
// First row
df.head(Some(1))
// Out:
// shape: (1, 3)
// ┌─────────┬─────┬────────┐
// │ Name    ┆ Age ┆ Height │
// │ ---     ┆ --- ┆ ---    │
// │ str     ┆ i32 ┆ f64    │
// ╞═════════╪═════╪════════╡
// │ Mahmoud ┆ 23  ┆ 1.84   │
// └─────────┴─────┴────────┘

// %% [markdown]
// ### Tail

// %%
let df: DataFrame = df!("Name" => &["Mahmoud", "Bob"],
                                      "Age" => &[23, 27],
                                      "Height" => &[1.84, 1.78])?;
// Last 10 rows
df.tail(None)
// Out:
// shape: (2, 3)
// ┌─────────┬─────┬────────┐
// │ Name    ┆ Age ┆ Height │
// │ ---     ┆ --- ┆ ---    │
// │ str     ┆ i32 ┆ f64    │
// ╞═════════╪═════╪════════╡
// │ Mahmoud ┆ 23  ┆ 1.84   │
// │ Bob     ┆ 27  ┆ 1.78   │
// └─────────┴─────┴────────┘

// %%
let df: DataFrame = df!("Name" => &["Mahmoud", "Bob"],
                                      "Age" => &[23, 27],
                                      "Height" => &[1.84, 1.78])?;
// Last row
df.tail(Some(1))
// Out:
// shape: (1, 3)
// ┌──────┬─────┬────────┐
// │ Name ┆ Age ┆ Height │
// │ ---  ┆ --- ┆ ---    │
// │ str  ┆ i32 ┆ f64    │
// ╞══════╪═════╪════════╡
// │ Bob  ┆ 27  ┆ 1.78   │
// └──────┴─────┴────────┘

// %% [markdown]
// ### Indexing & Slicing

// %%
{
    let df: DataFrame = df!("Name" => &["Mahmoud", "Ali", "ThePrimeagen"],
             "Age" => &[22, 25, 29],
             "Gender" => &["M", "M", "M"],
             "Salary" => &[50000, 60000, 250000])?;
    let name_col: &Column = &df["Name"];
    // or
    // let name_col1: &Column = &df[0];
    println!("{:?}", name_col);
}
// Out:
// Series(SeriesColumn { inner: shape: (3,)
// Series: 'Name' [str]
// [
// 	"Mahmoud"
// 	"Ali"
// 	"ThePrimeagen"
// ], materialized_at: None })
// ()

// %%
let df: DataFrame = df!("Name" => &["Mahmoud", "Ali", "ThePrimeagen"],
             "Age" => &[22, 25, 29],
             "Gender" => &["M", "M", "M"],
             "Salary" => &[50000, 60000, 250000])?;

let name_age_cols: DataFrame = df.select(["Name", "Age"])?;
name_age_cols
// Out:
// shape: (3, 2)
// ┌──────────────┬─────┐
// │ Name         ┆ Age │
// │ ---          ┆ --- │
// │ str          ┆ i32 │
// ╞══════════════╪═════╡
// │ Mahmoud      ┆ 22  │
// │ Ali          ┆ 25  │
// │ ThePrimeagen ┆ 29  │
// └──────────────┴─────┘

// %%
let df: DataFrame = df!("Name" => &["Mahmoud", "Ali", "ThePrimeagen"],
             "Age" => &[22, 25, 29],
             "Gender" => &["M", "M", "M"],
             "Salary" => &[50000, 60000, 250000])?;

{
    let name_col = df.column("Name");
    println!("{:?}", name_col);
}
// Out:
// Ok(Series(SeriesColumn { inner: shape: (3,)
// Series: 'Name' [str]
// [
// 	"Mahmoud"
// 	"Ali"
// 	"ThePrimeagen"
// ], materialized_at: None }))
// ()

// %%
let df: DataFrame = df!("Name" => &["Mahmoud", "Ali", "ThePrimeagen"],
             "Age" => &[22, 25, 36],
             "Gender" => &["M", "M", "M"],
             "Salary" => &[50000, 60000, 250000])?;


let mask: ChunkedArray<BooleanType> = df.column("Age").expect("Age must exist!").i32().expect("Age must be u32").gt(25);
let filtered_data: DataFrame = df.filter(&mask).unwrap();
println!("{:?}", filtered_data);
// Out:
// shape: (1, 4)
// ┌──────────────┬─────┬────────┬────────┐
// │ Name         ┆ Age ┆ Gender ┆ Salary │
// │ ---          ┆ --- ┆ ---    ┆ ---    │
// │ str          ┆ i32 ┆ str    ┆ i32    │
// ╞══════════════╪═════╪════════╪════════╡
// │ ThePrimeagen ┆ 36  ┆ M      ┆ 250000 │
// └──────────────┴─────┴────────┴────────┘

// %%
let df: DataFrame = df!("Name" => &["Mahmoud", "Ali", "ThePrimeagen"],
             "Age" => &[22, 25, 36],
             "Gender" => &["M", "M", "M"],
             "Salary" => &[50000, 60000, 250000])?;

df.slice(2, 3)
// Out:
// shape: (1, 4)
// ┌──────────────┬─────┬────────┬────────┐
// │ Name         ┆ Age ┆ Gender ┆ Salary │
// │ ---          ┆ --- ┆ ---    ┆ ---    │
// │ str          ┆ i32 ┆ str    ┆ i32    │
// ╞══════════════╪═════╪════════╪════════╡
// │ ThePrimeagen ┆ 36  ┆ M      ┆ 250000 │
// └──────────────┴─────┴────────┴────────┘

// %%
let mut df: DataFrame = df!("Name" => &["Mahmoud", "Ali", "ThePrimeagen"],
             "Age" => &[22, 25, 36],
             "Gender" => &["M", "M", "M"],
             "Salary" => &[50000, 60000, 250000])?;

df.transpose(Some("columns"), Some(Either::Right(vec!["Person 1".to_string(), "Person 2".to_string(), "Person 3".to_string()])))?
// Out:
// shape: (4, 4)
// ┌─────────┬──────────┬──────────┬──────────────┐
// │ columns ┆ Person 1 ┆ Person 2 ┆ Person 3     │
// │ ---     ┆ ---      ┆ ---      ┆ ---          │
// │ str     ┆ str      ┆ str      ┆ str          │
// ╞═════════╪══════════╪══════════╪══════════════╡
// │ Name    ┆ Mahmoud  ┆ Ali      ┆ ThePrimeagen │
// │ Age     ┆ 22       ┆ 25       ┆ 36           │
// │ Gender  ┆ M        ┆ M        ┆ M            │
// │ Salary  ┆ 50000    ┆ 60000    ┆ 250000       │
// └─────────┴──────────┴──────────┴──────────────┘

// %% [markdown]
// ## Data Cleaning

// %% [markdown]
// ### Nulls Count

// %%
let df: DataFrame = df!("Name" => &[Some("Mahmoud"),  None, None],
             "Age" => &[22, 25, 36],
             "Gender" => &["M", "M", "M"],
             "Salary" => &[50000, 60000, 250000])?;

df.null_count()
// Out:
// shape: (1, 4)
// ┌──────┬─────┬────────┬────────┐
// │ Name ┆ Age ┆ Gender ┆ Salary │
// │ ---  ┆ --- ┆ ---    ┆ ---    │
// │ u32  ┆ u32 ┆ u32    ┆ u32    │
// ╞══════╪═════╪════════╪════════╡
// │ 2    ┆ 0   ┆ 0      ┆ 0      │
// └──────┴─────┴────────┴────────┘

// %% [markdown]
// ### Duplicates

// %%
let df: DataFrame = df!("Name" => &["Mahmoud",  "Mahmoud", "ThePrimeagen"],
             "Age" => &[22, 22, 36],
             "Gender" => &["M", "M", "M"],
             "Salary" => &[50000, 50000, 250000])?;
let mask: ChunkedArray<BooleanType> = df.is_duplicated()?;
let filtered_data: DataFrame = df.filter(&mask)?;
filtered_data
// Out:
// shape: (2, 4)
// ┌─────────┬─────┬────────┬────────┐
// │ Name    ┆ Age ┆ Gender ┆ Salary │
// │ ---     ┆ --- ┆ ---    ┆ ---    │
// │ str     ┆ i32 ┆ str    ┆ i32    │
// ╞═════════╪═════╪════════╪════════╡
// │ Mahmoud ┆ 22  ┆ M      ┆ 50000  │
// │ Mahmoud ┆ 22  ┆ M      ┆ 50000  │
// └─────────┴─────┴────────┴────────┘

// %% [markdown]
// ### Unique Values

// %%
let df: DataFrame = df!("Name" => &["Mahmoud",  "Mahmoud", "ThePrimeagen"],
             "Age" => &[22, 22, 36],
             "Gender" => &["M", "M", "M"],
             "Salary" => &[50000, 50000, 250000])?;
let mask: ChunkedArray<BooleanType> = df.is_unique().unwrap();
let filtered_data: DataFrame = df.filter(&mask)?;
filtered_data
// Out:
// shape: (1, 4)
// ┌──────────────┬─────┬────────┬────────┐
// │ Name         ┆ Age ┆ Gender ┆ Salary │
// │ ---          ┆ --- ┆ ---    ┆ ---    │
// │ str          ┆ i32 ┆ str    ┆ i32    │
// ╞══════════════╪═════╪════════╪════════╡
// │ ThePrimeagen ┆ 36  ┆ M      ┆ 250000 │
// └──────────────┴─────┴────────┴────────┘

// %% [markdown]
// ### Drop

// %%
let df: DataFrame = df!("Fruit" => &["Apple", "Apple", "Pear"],
                        "Color" => &["Red", "Yellow", "Green"])?;
let df_remain: DataFrame = df.drop("Color")?; 
println!("{}", df_remain);
println!("{}", df); // the original DataFrame
// Out:
// shape: (3, 1)
// ┌───────┐
// │ Fruit │
// │ ---   │
// │ str   │
// ╞═══════╡
// │ Apple │
// │ Apple │
// │ Pear  │
// └───────┘
// shape: (3, 2)
// ┌───────┬────────┐
// │ Fruit ┆ Color  │
// │ ---   ┆ ---    │
// │ str   ┆ str    │
// ╞═══════╪════════╡
// │ Apple ┆ Red    │
// │ Apple ┆ Yellow │
// │ Pear  ┆ Green  │
// └───────┴────────┘

// %%
let mut df: DataFrame = df!("Fruit" => &["Apple", "Apple", "Pear"],
                                      "Color" => &["Red", "Yellow", "Green"])?;
df.drop_in_place("Color")?; // remove the row with index 1 ("Banana") from df
df
// Out:
// shape: (3, 1)
// ┌───────┐
// │ Fruit │
// │ ---   │
// │ str   │
// ╞═══════╡
// │ Apple │
// │ Apple │
// │ Pear  │
// └───────┘

// %%
let df: DataFrame = df!("Fruit" => &["Apple", "Apple", "Pear"],
                                      "Color" => &["Red", "Yellow", "Green"])?;
let df_dropped_col: DataFrame = df.drop_many(["Color", ""]);
df_dropped_col
// Out:
// shape: (3, 1)
// ┌───────┐
// │ Fruit │
// │ ---   │
// │ str   │
// ╞═══════╡
// │ Apple │
// │ Apple │
// │ Pear  │
// └───────┘

// %%
let df: DataFrame = df!("Fruit" => &["Apple", "Apple", "Pear"],
                                      "Color" => &[Some("Red"), None, None])?;
let df_clean: DataFrame = df.drop_nulls::<String>(None)?;
df_clean
// Out:
// shape: (1, 2)
// ┌───────┬───────┐
// │ Fruit ┆ Color │
// │ ---   ┆ ---   │
// │ str   ┆ str   │
// ╞═══════╪═══════╡
// │ Apple ┆ Red   │
// └───────┴───────┘

// %%
let df: DataFrame = df!("Name" => &["Mahmoud", "Ali", "ThePrimeagen"],
             "Age" => &[22, 25, 36],
             "Gender" => &["M", "M", "M"],
             "Salary" => &[Some(50000), Some(60000), None])?;
let mask: ChunkedArray<BooleanType> = df.column("Salary").expect("Salary must exist!").is_not_null();
mask.head(None)
// Out:
// shape: (3,)
// ChunkedArray: 'Salary' [bool]
// [
// 	true
// 	true
// 	false
// ]

// %%
let df: DataFrame = df!("Name" => &["Mahmoud", "Ali", "ThePrimeagen"],
             "Age" => &[22, 25, 36],
             "Gender" => &["M", "M", "M"],
             "Salary" => &[Some(50000), Some(60000), None])?;
let filtered_data: DataFrame = df.filter(&mask)?;
filtered_data
// Out:
// shape: (2, 4)
// ┌─────────┬─────┬────────┬────────┐
// │ Name    ┆ Age ┆ Gender ┆ Salary │
// │ ---     ┆ --- ┆ ---    ┆ ---    │
// │ str     ┆ i32 ┆ str    ┆ i32    │
// ╞═════════╪═════╪════════╪════════╡
// │ Mahmoud ┆ 22  ┆ M      ┆ 50000  │
// │ Ali     ┆ 25  ┆ M      ┆ 60000  │
// └─────────┴─────┴────────┴────────┘

// %% [markdown]
// ### Fill

// %%
let mut df: DataFrame = df!("Name" => &["Mahmoud", "Ali", "ThePrimeagen"],
             "Age" => &[22, 25, 36],
             "Gender" => &["M", "M", "M"],
             "Salary" => &[Some(50000), Some(60000), None])?;

let filtered_nulls: DataFrame = df.fill_null(FillNullStrategy::Forward(None))?;
filtered_nulls
// Out:
// shape: (3, 4)
// ┌──────────────┬─────┬────────┬────────┐
// │ Name         ┆ Age ┆ Gender ┆ Salary │
// │ ---          ┆ --- ┆ ---    ┆ ---    │
// │ str          ┆ i32 ┆ str    ┆ i32    │
// ╞══════════════╪═════╪════════╪════════╡
// │ Mahmoud      ┆ 22  ┆ M      ┆ 50000  │
// │ Ali          ┆ 25  ┆ M      ┆ 60000  │
// │ ThePrimeagen ┆ 36  ┆ M      ┆ 60000  │
// └──────────────┴─────┴────────┴────────┘

// %% [markdown]
// ## Measures of central tendency

// %% [markdown]
// ### Mean

// %%
let df: DataFrame = df!("Name" => &["Mahmoud", "Ali", "ThePrimeagen"],
             "Age" => &[22, 25, 36],
             "Gender" => &["M", "M", "M"],
             "Salary" => &[Some(50000), Some(60000), None])?;

df.lazy().mean().select([all().exclude_cols(["Name", "Gender"]).as_expr()]).collect()?
// Out:
// shape: (1, 2)
// ┌───────────┬─────────┐
// │ Age       ┆ Salary  │
// │ ---       ┆ ---     │
// │ f64       ┆ f64     │
// ╞═══════════╪═════════╡
// │ 27.666667 ┆ 55000.0 │
// └───────────┴─────────┘

// %% [markdown]
// ### Median

// %%
let df: DataFrame = df!("Name" => &["Mahmoud", "Ali", "ThePrimeagen"],
             "Age" => &[22, 25, 36],
             "Gender" => &["M", "M", "M"],
             "Salary" => &[Some(50000), Some(60000), None])?;

df.lazy().median().select([all().exclude_cols(["Name", "Gender"]).as_expr()]).collect()?
// Out:
// shape: (1, 2)
// ┌──────┬─────────┐
// │ Age  ┆ Salary  │
// │ ---  ┆ ---     │
// │ f64  ┆ f64     │
// ╞══════╪═════════╡
// │ 25.0 ┆ 55000.0 │
// └──────┴─────────┘

// %% [markdown]
// ## Measures of spread

// %% [markdown]
// ### std

// %%
let df: DataFrame = df!("Name" => &["Mahmoud", "Ali", "ThePrimeagen"],
             "Age" => &[22, 25, 36],
             "Gender" => &["M", "M", "M"],
             "Salary" => &[Some(50000), Some(60000), None])?;

df.lazy().std(1).select([all().exclude_cols(["Name", "Gender"]).as_expr()]).collect()?
// Out:
// shape: (1, 2)
// ┌──────────┬─────────────┐
// │ Age      ┆ Salary      │
// │ ---      ┆ ---         │
// │ f64      ┆ f64         │
// ╞══════════╪═════════════╡
// │ 7.371115 ┆ 7071.067812 │
// └──────────┴─────────────┘

// %% [markdown]
// ### var

// %%
let df: DataFrame = df!("Name" => &["Mahmoud", "Ali", "ThePrimeagen"],
             "Age" => &[22, 25, 36],
             "Gender" => &["M", "M", "M"],
             "Salary" => &[Some(50000), Some(60000), None])?;

df.lazy().var(1).select([all().exclude_cols(["Name", "Gender"]).as_expr()]).collect()?
// Out:
// shape: (1, 2)
// ┌───────────┬────────┐
// │ Age       ┆ Salary │
// │ ---       ┆ ---    │
// │ f64       ┆ f64    │
// ╞═══════════╪════════╡
// │ 54.333333 ┆ 5e7    │
// └───────────┴────────┘

// %% [markdown]
// ## Ndarray

// %%
let df: DataFrame = df!("Name" => &["Mahmoud", "Ali", "ThePrimeagen"],
             "Age" => &[22, 25, 36],
             "Gender" => &["M", "M", "M"],
             "Salary" => &[Some(50000), Some(60000), None])?;

df.to_ndarray::<Float64Type>(IndexOrder::Fortran).unwrap()
// Out:
// [[NaN, 22.0, NaN, 50000.0],
//  [NaN, 25.0, NaN, 60000.0],
//  [NaN, 36.0, NaN, NaN]], shape=[3, 4], strides=[1, 3], layout=Ff (0xa), const ndim=2

// %% [markdown]
// <hr />

// %% [markdown]
// ## Aggregation Functions

// %% [markdown]
// Download [the flights dataset](https://www.kaggle.com/datasets/deepak007chaubey/flight-on-time-dataset?select=Flight_on_time_HIX.csv) and move it to the `dataset` directory.

// %%
fn read_data_frame_from_csv(
    csv_file_path: &Path,
) -> DataFrame {
    CsvReadOptions::default()
        .with_has_header(true)
        .try_into_reader_with_file_path(Some(csv_file_path.to_path_buf())).unwrap()
        .finish()
        .unwrap()
}


let flights_file_path: &Path = Path::new("dataset/Flight_on_time_HIX.csv");
let columns = ["Airline", "Origin_Airport", "Destination_Airport", "Departure_Delay_Minutes", "Arrival_Delay_Minutes"];
let flights_df: DataFrame = read_data_frame_from_csv(flights_file_path).select(columns)?;
flights_df.head(Some(5))
// Out:
// shape: (5, 5)
// ┌─────────┬────────────────┬─────────────────────┬─────────────────────────┬───────────────────────┐
// │ Airline ┆ Origin_Airport ┆ Destination_Airport ┆ Departure_Delay_Minutes ┆ Arrival_Delay_Minutes │
// │ ---     ┆ ---            ┆ ---                 ┆ ---                     ┆ ---                   │
// │ str     ┆ str            ┆ str                 ┆ i64                     ┆ i64                   │
// ╞═════════╪════════════════╪═════════════════════╪═════════════════════════╪═══════════════════════╡
// │ TR      ┆ IYF            ┆ HIX                 ┆ 62                      ┆ 52                    │
// │ TR      ┆ HEN            ┆ HIX                 ┆ 15                      ┆ 8                     │
// │ RO      ┆ HIX            ┆ IZN                 ┆ 0                       ┆ 0                     │
// │ XM      ┆ HIX            ┆ IZU                 ┆ 34                      ┆ 44                    │
// ...

// %%
let arr_delay_mean_df: DataFrame = flights_df.group_by(["Airline"]).expect("Airline Column must exist!").select(["Arrival_Delay_Minutes"]).mean().unwrap();
arr_delay_mean_df.head(Some(5))
// Out:
// shape: (5, 2)
// ┌─────────┬────────────────────────────┐
// │ Airline ┆ Arrival_Delay_Minutes_mean │
// │ ---     ┆ ---                        │
// │ str     ┆ f64                        │
// ╞═════════╪════════════════════════════╡
// │ RO      ┆ 208.847044                 │
// │ VF      ┆ 40.816667                  │
// │ UG      ┆ 34.374332                  │
// │ TR      ┆ 281.309919                 │
// │ SN      ┆ 133.10991                  │
// └─────────┴────────────────────────────┘

// %%
let dep_delay_mean_def: DataFrame = flights_df.group_by(["Airline", "Origin_Airport"]).expect("Airline and Origin_Airport Columns must exist!").select(["Departure_Delay_Minutes"]).mean().unwrap();
dep_delay_mean_def.head(Some(5))
// Out:
// shape: (5, 3)
// ┌─────────┬────────────────┬──────────────────────────────┐
// │ Airline ┆ Origin_Airport ┆ Departure_Delay_Minutes_mean │
// │ ---     ┆ ---            ┆ ---                          │
// │ str     ┆ str            ┆ f64                          │
// ╞═════════╪════════════════╪══════════════════════════════╡
// │ NR      ┆ UKP            ┆ 17.866667                    │
// │ CA      ┆ VCN            ┆ 26.019608                    │
// │ RO      ┆ VCN            ┆ 15.176471                    │
// │ NR      ┆ HDU            ┆ 29.941176                    │
// │ FH      ┆ KZW            ┆ 5.853933                     │
// └─────────┴────────────────┴──────────────────────────────┘

// %% [markdown]
// <hr />

// %% [markdown]
// ## Merging DataFrames

// %% [markdown]
// ### Inner Join

// %%
let df1: DataFrame = df!("Carrier" => &["HA", "EV", "VX", "DL"],
                         "ArrDelay" => &[-3, 28, 0, 1])?;
let df2: DataFrame = df!("Airline" => &["HA", "EV", "OO", "VX"],
                         "DepDelay" => &[21, -8, 11, -4])?;

let df3: DataFrame = df1.join(&df2, ["Carrier"], ["Airline"], JoinType::Inner.into(), None)?;
// or
// let df3: DataFrame = df1.inner_join(&df2, ["Carrier"], ["Airline"])?;
df3.head(Some(5))
// Out:
// shape: (3, 3)
// ┌─────────┬──────────┬──────────┐
// │ Carrier ┆ ArrDelay ┆ DepDelay │
// │ ---     ┆ ---      ┆ ---      │
// │ str     ┆ i32      ┆ i32      │
// ╞═════════╪══════════╪══════════╡
// │ HA      ┆ -3       ┆ 21       │
// │ EV      ┆ 28       ┆ -8       │
// │ VX      ┆ 0        ┆ -4       │
// └─────────┴──────────┴──────────┘

// %% [markdown]
// ### Left Join

// %%
let df3: DataFrame = df1.left_join(&df2, ["Carrier"], ["Airline"])?;
df3.head(Some(5))
// Out:
// shape: (4, 3)
// ┌─────────┬──────────┬──────────┐
// │ Carrier ┆ ArrDelay ┆ DepDelay │
// │ ---     ┆ ---      ┆ ---      │
// │ str     ┆ i32      ┆ i32      │
// ╞═════════╪══════════╪══════════╡
// │ HA      ┆ -3       ┆ 21       │
// │ EV      ┆ 28       ┆ -8       │
// │ VX      ┆ 0        ┆ -4       │
// │ DL      ┆ 1        ┆ null     │
// └─────────┴──────────┴──────────┘

// %% [markdown]
// ### Right Join

// %%
let df4: DataFrame = df2.left_join(&df1, ["Airline"], ["Carrier"])?;
df4.head(Some(5))
// Out:
// shape: (4, 3)
// ┌─────────┬──────────┬──────────┐
// │ Airline ┆ DepDelay ┆ ArrDelay │
// │ ---     ┆ ---      ┆ ---      │
// │ str     ┆ i32      ┆ i32      │
// ╞═════════╪══════════╪══════════╡
// │ HA      ┆ 21       ┆ -3       │
// │ EV      ┆ -8       ┆ 28       │
// │ OO      ┆ 11       ┆ null     │
// │ VX      ┆ -4       ┆ 0        │
// └─────────┴──────────┴──────────┘

// %% [markdown]
// ### Full Join

// %%
let df5: DataFrame = df1.join(&df2, ["Carrier"], ["Airline"], JoinType::Full.into(), None)?;
df5.head(Some(5))
// Out:
// shape: (5, 4)
// ┌─────────┬──────────┬─────────┬──────────┐
// │ Carrier ┆ ArrDelay ┆ Airline ┆ DepDelay │
// │ ---     ┆ ---      ┆ ---     ┆ ---      │
// │ str     ┆ i32      ┆ str     ┆ i32      │
// ╞═════════╪══════════╪═════════╪══════════╡
// │ HA      ┆ -3       ┆ HA      ┆ 21       │
// │ EV      ┆ 28       ┆ EV      ┆ -8       │
// │ null    ┆ null     ┆ OO      ┆ 11       │
// │ VX      ┆ 0        ┆ VX      ┆ -4       │
// │ DL      ┆ 1        ┆ null    ┆ null     │
// └─────────┴──────────┴─────────┴──────────┘

// %% [markdown]
// <hr />
